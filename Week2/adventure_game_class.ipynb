# %%
class Room:
    name: str
    north: 'Room'
    east: 'Room'
    south: 'Room'
    west: 'Room'

    def __init__(self, name, north=None, east=None, south=None, west=None):
        self.name = name
        self.north = north
        self.east = east
        self.west = west
        self.south = south

        if north:
            north.south = self
        if east:
            east.west = self
        if south:
            south.north = self
        if west:
            west.east = self

    def go_to(self, direction):
        if direction in ['north','east','south','west']:
            return getattr(self, direction) 
        else:
            return None

    def __str__(self):
        return self.name

        #https://codereview.stackexchange.com/questions/259245/python-text-based-game-room-to-room-movement

# %%
import random

def displayIntro():
    print("inceputul povestii") 
    #video Doug McNally

def choosePath():
    path = ""

displayIntro()
# Out:
# inceputul povestii

# %%
rooms = ["kitchen", "living_room", "bedroom"]

print("Where are you now?")
print(input(rooms))
# Out:
# Where are you now?
# living_room

# %%
room = input("In which room are you now?")

print(room)
# Out:
# bedroom

# %%
rooms = {
    'entrance hall': {'east': 'kitchen', 'west': 'bedroom', 'north': 'lounge'},
    'kitchen': {'entrance hall': 'west'},
    'lounge': {'entrance hall': 'south'},
    'bedroom': {'entrance hall': 'east'}
}

rooms = input("In which room are you now?")
print(rooms)
# Out:
# Bedroom

# %%
rooms = {
    'entrance hall': {'east': 'kitchen', 'west': 'bedroom', 'north': 'lounge'},
    'kitchen': {'entrance hall': 'west'},
    'lounge': {'entrance hall': 'south'},
    'bedroom': {'entrance hall': 'east'}
}

print("It was a sunny day. ")
print("You are late and you run to your car, but realize you forgot your sunglasses")
print("You come back and start to move around the house to find them.")

gameOn = True

def move(player, direction):

    current_room = player
    if direction in rooms[current_room]:
        current_room = rooms[current_room][direction]
    
    else:
        print("There is nothing in that direction!")

        return current_room

def command():
    print("Find your sunglasess!")

def main():
    command()
    player = ('entrance hall', [])

    while gameOn:

        current_room = player
        print('f"\nYou are in the {current_room}')

        if player[0] == "kitchen":
            print('Your sunglasses are not here! Return to entrance hall!')
            break

main()
# Out:
#   Input In [14]
#     print("It was a sunny day. ")
#     ^
# IndentationError: unexpected indent

# %%
#Test based Adventure Game

import random

rooms = {
    'entrance hall': {'east': 'kitchen', 'west': 'bedroom', 'north': 'lounge'},
    'kitchen': {'entrance hall': 'west'},
    'lounge': {'entrance hall': 'south'},
    'bedroom': {'entrance hall': 'east'}
}

def current_room():
    current_room_options = ['entrance hall', 'kitchen', 'lounge', 'bedroom']
    user_choice = input("Where do you want to go?")


    print("--- povestea")
    print(user_choice)

#https://www.youtube.com/watch?v=ypNFNr72Xe8 
#explica logica de la inceputul game-ului

# Main program:
start_room()
# Out:
# --- povestea

# %%
import random

def msg(room):
    if room['msg'] == '':
        return "You have entered the " + room['name'] + '.'
    else:
        return room['msg']

def get_choice(room,dir):
    if dir == "N":
        choice = 0
    elif dir == "E":
        choice = 1
    elif dir == "S":
        choice = 2
    elif dir == 'W':
        choice = 3
    else:
        return -1

    if room['directions'][choice] == 0:
        return 4
    else:
        return get_choice

def main():
    dirs = (0, 0, 0, 0)

    entrance = {'name': 'Entrance Way', 'directions': dirs, 'msg': ''}
    kitchen = {'name': 'Kitchen', 'directions': dirs, 'msg': ''}
    livingroom = {'name': 'Living Room', 'directions': dirs, 'msg': ''}
    diningroom = {'name': 'Dining Room', 'directions': dirs, 'msg': ''}
    bedroom = {'name': 'Bedroom', 'directions': dirs, 'msg': ''}

    # directions (North, East, South, West)
    entrance['directions'] = (kitchen, livingroom, 0, 0)
    kitchen['directions'] = (0, diningroom, entrance, bedroom)
    livingroom['directions'] = (diningroom, 0, 0, entrance)
    diningroom['directions'] = (0, 0, livingroom, kitchen)
    bedroom['directions'] = (0, kitchen, 0, 0)

    # rooms where my sunglasses might be
    rooms = [kitchen, livingroom, diningroom, bedroom]
    room_with_sunglasses = random.choice(rooms)
    sunglasses_found = False
    room = entrance
    print("povestea")

    while True:
        if sunglasses_found and room['name'] == 'Entrance Way':
            print("You've found my sunglasses. Thank you! " +
                    'I can go to work now.')
            break;
        elif not sunglasses_found and room['name'] == room_with_sunglasses:
            sunglasses_found = True
            print(msg(room) + 'You found my sunglasses. You are a star!' +
                'You can leave.')
            room['msg'] = ('You are back in the ' + room['name'] + 
                        '! You already found the sunglasses. ' +
                        'You can go now.')
        else:
            print(msg(room))
            room['msg'] = 'You are back in the ' + room['name']

        stuck = True
        while stuck:
            dir = input("Which direction do you want to go: N, E, S or W?")
            choice = get_choice(room,dir)
            if choice == -1:
                print("Please enter N,E,S or W")
            elif choice == 4:
                print("You cannot go in that direction.")
            else:
                room = room['directions'][choice]
                stuck = False

main()
# Out:
# povestea
# You have entered the Entrance Way.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/crimarin007/Data science bootcamp/Week2/adventure_game_test.ipynb Cell 8' in <cell line: 77>()
#      <a href='vscode-notebook-cell:/home/crimarin007/Data%20science%20bootcamp/Week2/adventure_game_test.ipynb#ch0000007?line=73'>74</a>                 room = room['directions'][choice]
#      <a href='vscode-notebook-cell:/home/crimarin007/Data%20science%20bootcamp/Week2/adventure_game_test.ipynb#ch0000007?line=74'>75</a>                 stuck = False
# ---> <a href='vscode-notebook-cell:/home/crimarin007/Data%20science%20bootcamp/Week2/adventure_game_test.ipynb#ch0000007?line=76'>77</a> main()
#
# /home/crimarin007/Data science bootcamp/Week2/adventure_game_test.ipynb Cell 8' in main()
# ...

# %%
import random

def msg(room):
    if room['msg'] == '':
        return "You have entered the " + room['name'] + '.'
    else:
        return room['msg']

def get_choice(room,dir):
    if dir == "N":
        choice = 0
    elif dir == "E":
        choice = 1
    elif dir == "S":
        choice = 2
    elif dir == 'W':
        choice = 3
    else:
        return -1

    if room['directions'][choice] == 0:
        return 4
    else:
        return get_choice

def main():
    print("It is a sunny day! I'm late for work and I'm in a big rush. ")
    print("But when I got in my car I realised that I don't have my sunglases and I can't drive without them.")
    print("Can you help me find them?")


    # directions (North, East, South, West)
    entrance['directions'] = (kitchen, livingroom, 0, 0)
    kitchen['directions'] = (0, diningroom, entrance, bedroom)
    livingroom['directions'] = (diningroom, 0, 0, entrance)
    diningroom['directions'] = (0, 0, livingroom, kitchen)
    bedroom['directions'] = (0, kitchen, 0, 0)

    # rooms where my sunglasses might be
    rooms = [kitchen, livingroom, diningroom, bedroom]
    room_with_sunglasses = random.choice(rooms)
    sunglasses_found = False
    room = entrance
    print("You've started to look for my sunglases" + ". " + 'But where are they?')

    while True:
        if sunglasses_found and room['name'] == 'Entrance Way':
            print("You've found my sunglasses. Thank you! " +
                    'I can go to work now.')
            break
        elif not sunglasses_found and room['name'] == room_with_sunglasses:
            sunglasses_found = True
            print(msg(room) + 'You found my sunglasses. You are a star!' +
                'Thank you!')
            room['msg'] = ('You are back in the ' + room['name'] + 
                        '! You already found the sunglasses. ' +
                        'You can go now.')
        else:
            print(msg(room))
            room['msg'] = 'You are back in the ' + room['name']

        stuck = True
        while stuck:
            dir = input("Which direction do you want to go: N, E, S or W?")
            choice = get_choice(room,dir)
            if choice == -1:
                print("Please enter N,E,S or W")
            elif choice == 4:
                print("You cannot go in that direction.")
            else:
                room = room[dirs][choice]
                stuck = False

main()
# Out:
# It is a sunny day! I'm late for work and I'm in a big rush.
# But when I got in my car I realised that I don't have my sunglases and I can't drive without them.
# Can you help me find them?
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/crimarin007/Data science bootcamp/Week2/adventure_game_test.ipynb Cell 9' in <cell line: 75>()
#      <a href='vscode-notebook-cell:/home/crimarin007/Data%20science%20bootcamp/Week2/adventure_game_test.ipynb#ch0000008?line=71'>72</a>                 room = room[dirs][choice]
#      <a href='vscode-notebook-cell:/home/crimarin007/Data%20science%20bootcamp/Week2/adventure_game_test.ipynb#ch0000008?line=72'>73</a>                 stuck = False
# ---> <a href='vscode-notebook-cell:/home/crimarin007/Data%20science%20bootcamp/Week2/adventure_game_test.ipynb#ch0000008?line=74'>75</a> main()
#
# ...

# %%
rooms = {'Hallway': {'name': 'Hallway', 'East': 'Living Room', 'North': 'Kitchen'},
    'Bedroom': {'name': 'Bedroom', 'East': 'Kitchen'},
    'Living Room': {'name': 'Living Room', 'West': "Hallway", 'North': 'Dining room'},
    'Dining Room': {'name': 'Dining Room', 'West': 'Kitchen', 'South': 'Living Room'}
    'Kitchen': {'name': 'Kitchen', 'East': 'Dining Room', 'West': 'Bedroom', 'South': 'Hallway'},
}

directions = ['North', 'South', 'East', 'West']
current_room = rooms['Hallway']

while True:

print(poveste)
print('You are in the {}.'.format(current_room['name']))

command = input('What direction do you want to go?').strip()
if command in directions:
    if command in current_room:
        current_room = rooms[current_room[command]]
        else:
            print("You can't go that way.")
   elif command.lower() in ('q', 'quit'):
       break
   else:
       print('I do not understant that command.')
# Out:
#   File <tokenize>:22
#     elif command.lower() in ('q', 'quit'):
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
rooms = {
    'Front Lobby': {'West': 'Ice Rink'},
    'Ice Rink': {'North': 'Away Locker Room', 'East': 'Front Lobby', 'West': 'Mens Locker Room', 'South': 'Lounge'},
    'Away Locker Room': {'East': 'Pro Shop', 'South': 'Ice Rink'},
    'Pro Shop': {'West': 'Away Locker Room'},
    'Mens Locker Room': {'West': 'Ice Rink'},
    'Lounge': {'West': 'Womens Locker Room', 'East': 'Skate Rentals', 'North': 'Ice Rink'},
    'Womens Locker Room': {'East': 'Lounge'},
    'Skate Rentals': {'West': 'Lounge'}
}
gameOn = True
inventory = ['place holder']

#moves player from room to room
def move(player, direction):
    global rooms
    current_room = player 

    # check if there is a room in the specified direction
    if direction in rooms[current_room]:
        current_room = rooms[current_room][direction]

    # error handling
    else:
        print("There is nothing in that direction!")
        return player # Returning the same room if nothing Exists in the direction

    # return the player state
    return current_room # Indent Error

#displays rules at start of game 
def showRules():

    print("- Collect 6 items to win the game, or have to get clowned by the other goalie.\n" "Move commands: go South, go North, go East, go West.\n" "Add to Inventory: get 'item name'. Once all items collected type: ‘Finish’")


def main():
    showRules()
    player = "Front Lobby" # Acc. to me player should be a str not  tuple

    while gameOn:

        current_room = player

        # output
        print(f"\nYou are in the {current_room}")

        # Goalie got you
        if player == 'Pro Shop':
            print('You make more excuses than saves. GAME OVER')
            break

        # input validation and parsing
        print("----------------")
        player_move = input("Enter your move:\n") # because move is already a function

        # invalid move syntax
        if 'go' in player_move or 'Finish' in player_move:
                
    
            # split string 
            
            action = player_move.split(' ')
            print(action)        # move 
            if action[0] == 'go':
                player = move(player, action[1]) # Assigning the value to player 
                                                 # and giving a value since arg 
                                                 # isn't anything
            elif action == 'Finish':
                print('Awesome! Now get on the ice! You Win.')
    
            # invalid action
            else:
                print("Invalid command!")
        
        else:
            print('Invalid Command')
            continue


    

main()
# Out:
# - Collect 6 items to win the game, or have to get clowned by the other goalie.
# Move commands: go South, go North, go East, go West.
# Add to Inventory: get 'item name'. Once all items collected type: ‘Finish’
#
# You are in the Front Lobby
# ----------------
# Invalid Command
#
# You are in the Front Lobby
# ----------------
# Invalid Command
#
# You are in the Front Lobby
# ----------------
# Invalid Command
#
# You are in the Front Lobby
# ----------------
# Invalid Command
#
# You are in the Front Lobby
# ----------------
# Invalid Command
#
# You are in the Front Lobby
# ----------------
# Invalid Command
#
# You are in the Front Lobby
# ----------------
# Invalid Command
#
# You are in the Front Lobby
# ----------------
# Invalid Command
#
# You are in the Front Lobby
# ----------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ...

# %%
def intro():
    print("""
    It is a sunny day! I'm late for work and I'm in a big rush.
    But when I got in my car I realised that I don't have my sunglases and I can't drive without them.
    Would you like to help me?
    """)

    answer = input("Would you like to help me? (yes/no)")
    if answer == 'yes':
        print(answer)

    else:
        print("That's to bad!")

intro()
# Out:
#     It is a sunny day! I'm late for work and I'm in a big rush.
#     But when I got in my car I realised that I don't have my sunglases and I can't drive without them.
#     Would you like to help me?
#
# That's to bad!

# %%
def intro():
    print("""
    It is a sunny day! I'm late for work and I'm in a big rush.
    But when I got in my car I realised that I don't have my sunglases and I can't drive without them.
    Would you like to help me?
    """)

    answer = input("Would you like to help me? (yes/no)")
    directions = ['north', 'south', 'east', 'west', 'n', 's', 'e', 'w']

    if answer == 'yes':
        print("You are now in Hallway! Where do you want to go next?")
        answer = input(directions)
        if answer == "north":
            print("You are in the Kitchen. Have you found my sunglasses? (yes/no)")
            answer == input("Have you found my sunglasses?")
            if answer == "yes":
                print("Thank you. You are a star! Now I can go to work now!")
            else:
                print("Keep looking. Check into another room.")
        elif answer == "south":
            print('You can not go in that direction.')
        elif answer == "west":
            print('You can not go in that direction.')
        elif answer == "east":
            print("You are in the Living Room. Have you found my sunglasses? (yes/no)")
            answer = input("Have you found my sunglasses?")
            if answer == "yes":
                print("Thank you. You are a star! I can go to work now!")
            else:
                print("Keep looking. Check into another room.")
        else:
            print("Keep looking!")

    else:
        print("That's to bad!")

intro()
# Out:
#     It is a sunny day! I'm late for work and I'm in a big rush.
#     But when I got in my car I realised that I don't have my sunglases and I can't drive without them.
#     Would you like to help me?
#
# You are now in Hallway! Where do you want to go next?
# You are in the Living Room. Have you found my sunglasses? (yes/no)
# Thank you. You are a star! I can go to work now!
