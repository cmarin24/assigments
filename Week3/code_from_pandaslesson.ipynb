# %%
{
 "cells": [
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": []
  },
  {
   "cell_type": "code",
   "execution_count": 44,
   "metadata": {},
   "outputs": [
    {
     "name": "stdout",
     "output_type": "stream",
     "text": [
      "7\n",
      "   a  b\n",
      "x  1  4\n",
      "y  2  5\n",
      "z  3  8\n"
     ]
    },
    {
     "data": {
      "text/html": [
       "<div>\n",
       "<style scoped>\n",
       "    .dataframe tbody tr th:only-of-type {\n",
       "        vertical-align: middle;\n",
       "    }\n",
       "\n",
       "    .dataframe tbody tr th {\n",
       "        vertical-align: top;\n",
       "    }\n",
       "\n",
       "    .dataframe thead th {\n",
       "        text-align: right;\n",
       "    }\n",
       "</style>\n",
       "<table border=\"1\" class=\"dataframe\">\n",
       "  <thead>\n",
       "    <tr style=\"text-align: right;\">\n",
       "      <th></th>\n",
       "      <th>a</th>\n",
       "      <th>b</th>\n",
       "      <th>c</th>\n",
       "    </tr>\n",
       "  </thead>\n",
       "  <tbody>\n",
       "    <tr>\n",
       "      <th>x</th>\n",
       "      <td>1</td>\n",
       "      <td>4</td>\n",
       "      <td>7</td>\n",
       "    </tr>\n",
       "    <tr>\n",
       "      <th>y</th>\n",
       "      <td>2</td>\n",
       "      <td>5</td>\n",
       "      <td>8</td>\n",
       "    </tr>\n",
       "    <tr>\n",
       "      <th>z</th>\n",
       "      <td>3</td>\n",
       "      <td>8</td>\n",
       "      <td>9</td>\n",
       "    </tr>\n",
       "  </tbody>\n",
       "</table>\n",
       "</div>"
      ],
      "text/plain": [
       "   a  b  c\n",
       "x  1  4  7\n",
       "y  2  5  8\n",
       "z  3  8  9"
      ]
     },
     "execution_count": 44,
     "metadata": {},
     "output_type": "execute_result"
    }
   ],
   "source": [
    "# df = pd.DataFrame({\n",
    "#     'a' : [1,2,3,4,5],\n",
    "#     'b' : [5,4,3,2,5],\n",
    "#     'c' : [1,2,3,4,5],\n",
    "# })\n",
    "\n",
    "indexList = ['x', 'y', 'z']\n",
    "columnList = ['a', 'b', 'c']\n",
    "\n",
    "df = pd.DataFrame([\n",
    "    [1,4,7],\n",
    "    [2,5,8],\n",
    "    [3,8,9],\n",
    "], index = indexList, columns=columnList)\n",
    "\n",
    "# print(df.iloc[0:2,0:2])\n",
    "# print(df.loc['x', 'a'])\n",
    "\n",
    "print(df.loc['x', 'c'])\n",
    "print(df.loc['x':'z', 'a' : 'b'])\n",
    "\n",
    "\n",
    "df"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": 142,
   "metadata": {},
   "outputs": [
    {
     "data": {
      "text/plain": [
       "array([<AxesSubplot:title={'center':'total_bill'}>], dtype=object)"
      ]
     },
     "execution_count": 142,
     "metadata": {},
     "output_type": "execute_result"
    },
    {
     "data": {
      "image/png": "...",
      "text/plain": [
       "<Figure size 432x288 with 1 Axes>"
      ]
     },
     "metadata": {},
     "output_type": "display_data"
    },
    {
     "data": {
      "image/png": "...",
      "text/plain": [
       "<Figure size 432x288 with 2 Axes>"
      ]
     },
     "metadata": {
      "needs_background": "light"
     },
     "output_type": "display_data"
    }
   ],
   "source": [
    "tipsData = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv')\n",
    "\n",
    "# print(tipsData.head(5))\n",
    "# print(tipsData.tail(10))\n",
    "# print(tipsData.sample(10))\n",
    "# print(tipsData.describe())\n",
    "\n",
    "# tipsData.isnull().sum()\n",
    "tipDayPercentage = 100* tipsData.groupby(['day']).sum()['tip'] / tipsData.groupby(['day']).sum()['total_bill']\n",
    "# print(tipsData.groupby(['day']).sum())\n",
    "# print(100 * tipsData.groupby(['day']).sum()['tip']/ tipsData.groupby(['day']).sum()['total_bill'])\n",
    "\n",
    "tipDayPercentage = tipDayPercentage.to_frame('tip(%)').reset_index()\n",
    "\n",
    "\n",
    "# fig, ax = plt.subplots(1,2)\n",
    "\n",
    "# tipDayPercentage.plot(kind ='bar', x = 'day', y = 'tip(%)', color = 'red', ax = ax[0])\n",
    "# tipDayPercentage.plot(kind ='bar', color = 'red', ax = ax[1])\n",
    "\n",
    "# print(tipsData.head(10))\n",
    "\n",
    "# print(tipsData['day'].value_counts())\n",
    "days = pd.DataFrame(tipsData['day'].value_counts())\n",
    "days.reset_index(inplace=True)\n",
    "\n",
    "\n",
    "\n",
    "fig, pltAx = plt.subplots()\n",
    "days.plot(kind = 'pie', y = 'day', labels = days['index'], autopct='%1.2f', ax = pltAx)\n",
    "\n",
    "fig, pltAx = plt.subplots(1,2)\n",
    "tipsData.hist(column='total_bill', ax = pltAx[0])\n",
    "tipsData.hist(column='total_bill', bins = 100, ax = pltAx[1])\n"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": 140,
   "metadata": {},
   "outputs": [
    {
     "name": "stdout",
     "output_type": "stream",
     "text": [
      "    Sales Person           School Sales Lead  Number of Teachers in School  \\\n",
      "42  Barney Baker  Trotts Hill Primary School                            30   \n",
      "\n",
      "   Initial Contact Date Contact Method Sales Meet Accepted Sales Meet Date  \\\n",
      "42             7/4/2018          Email                 Yes      15/07/2018   \n",
      "\n",
      "   School Acquired?  Number of Teachers in Package? Revenue per Year  \n",
      "42               No                             NaN              NaN  \n"
     ]
    }
   ],
   "source": []
  }
 ],
 "metadata": {
  "language_info": {
   "name": "python"
  },
  "orig_nbformat": 4
 },
 "nbformat": 4,
 "nbformat_minor": 2
}
